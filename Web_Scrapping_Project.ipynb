# %% [markdown]
# # Web Scrapping Project

# %% [markdown]
# In this project, we will do Web Scrapping to scrape weather data from Weather.com by using techniques such as requests and BeautifulSoup.

# %% [markdown]
# ## Table of contents
# * Importing required libraries
# * Definition of URL
# * Requests and HTML Response
# * Parsing HTML with BeautifulSoup
# * Scrapping HTML to extract our data
# * Storing data in Pandas DataFrame
# * Resulting DataFrame
# * Exporting the data to CSV file

# %% [markdown]
# ## Importing required libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Definition of URL

# %% [markdown]
# The following URL shows as result the weather in Barcelona from Google Search.

# %%
url = "https://weather.com/en-IN/weather/tenday/l/15a6ad947775a7db2af7ce30fdf62def9c2d764127ac7b2db178053265e1bb70"

# %% [markdown]
# ## Requests and HTML Response

# %%
# getting response from the url: 
response = requests.get(url)

# %%
# checking server status code is successful:
response.status_code
# Out:
# 200

# %%
# checking response content:
# response.content

# %% [markdown]
# ## Parsing HTML with BeautifulSoup

# %%
# Applying BeautifulSoup to response:
soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# ## Scrapping HTML to extract our data

# %%
# parsing weather location: 
location = soup.find("span",{"class": "LocationPageTitle--PresentationName--1QYny"})
location.getText().strip('-')
# Out:
# 'Barcelona, Barcelona, Spain'

# %%
# parsing timestamp of weather data:
timestamp = soup.find("div",{"class": "DailyForecast--timestamp--22ExT"})
timestamp.getText().strip()
# Out:
# 'As of 00:25 CEST'

# %%
# parsing days of weather data scrapped:
days = soup.findAll("h3",{"class": "DailyContent--daypartName--1bzYn"})

# storing days and day parts in lists: 
days_list = [i.getText().split("| ")[0] for i in days]
day_part = [i.getText().split("| ")[1] for i in days]

# %%
# parsing temperature:
temp = soup.select("span.DailyContent--temp--3d4dn")

# storing highest_temp in a list: 
temp_list = [i.getText().strip() for i in temp]

# %%
# parsing % rain and wind:
rain_wind = soup.select("div.DailyContent--label--3Ok7H")

# storing rain and wind in a list: 
rain_wind_list = [i.getText().strip() for i in rain_wind]
rain_wind_list

# splitting into independant lists: 
rain_perc_list = [i.replace('Rain','') for i in rain_wind_list[::2]]
wind_list = [i.replace('Wind','') for i in rain_wind_list[1::2]]

# %%
# parsing humidity %: 
humidity_perc = soup.findAll("span",{"data-testid": "PercentageValue", "class": "DetailsTable--value--1q_qD"})

# storing in a list: 
humidity_perc_list = [i.getText() for i in humidity_perc]

# %%
# parsing weather_description:
weather_description = soup.select("p.DailyContent--narrative--hplRl")

# parsing weather_description in a list: 
weather_description = [i.getText().strip() for i in weather_description]

# %% [markdown]
# ## Storing data in Pandas DataFrame

# %% [markdown]
# Once we have scrapped all our data, we will collect in a dictionary, which will be then converted to a Pandas DataFrame.

# %%
weather_data = pd.DataFrame({
    "location": location, 
    "timestamp": timestamp, 
    "day": days_list, 
    "day part": day_part,
    "temperature": temp_list,
    "rain %": rain_perc_list,
    "wind": wind_list, 
    "humidity %": humidity_perc_list,
    "description": weather_description
})

# %% [markdown]
# 9          28°     3%  ESE 16 km/h        61%
# 10         21°     5%  ENE 12 km/h        70%
# 11         29°     3%    E 17 km/h        63%
# 12         22°    19%  WSW 12 km/h        66%
# 13         30°    19%  SSE 17 km/h        56%
# 14         22°     5%    W 13 km/h        62%
# 15         29°     4%   SE 18 km/h        56%
# 16         22°     7%  WSW 15 km/h        69%
# 17         28°     7%   SE 18 km/h        62%
# 18         21°    15%  WSW 15 km/h        75%
# 19         28°     7%  SSE 18 km/h        64%
# 20         21°    12%   SW 16 km/h        71%
# 21         27°    16%   SE 19 km/h        62%
# 22         20°    11%  SSW 16 km/h        73%
# 23         27°    10%  SSE 18 km/h        63%
# 24         20°     3%   SW 16 km/h        73%
# 25         27°     6%  SSE 18 km/h        63%
# 26         20°     9%  SSW 16 km/h        73%
# 27         27°     8%  SSE 18 km/h        62%
# 28         21°    13%   SW 15 km/h        72%
#
#                                           description
# 0   Generally clear. Low 20ºC. Winds WNW and varia...
# 1   Generally clear. High 29ºC. Winds SSW at 15 to...
# 2   Generally clear. Low 21ºC. Winds WSW at 10 to ...
# 3   Generally clear. High 29ºC. Winds SSW at 15 to...
# 4   Partly cloudy. Low 21ºC. Winds WSW at 15 to 25...
# 5   Partly cloudy. High 30ºC. Winds S at 10 to 15 ...
# 6   Partly cloudy. Low 21ºC. Winds WSW at 10 to 15...
# 7   Partly cloudy. High 29ºC. Winds SE at 10 to 15...
# 8   Partly cloudy. Low 21ºC. Winds WSW at 10 to 15...
# 9   Partly cloudy. High 28ºC. Winds ESE at 10 to 1...
# 10  Partly cloudy. Low 21ºC. Winds ENE at 10 to 15...
# 11  Generally clear. High 29ºC. Winds E at 10 to 1...
# 12  Partly cloudy. Low 22ºC. Winds WSW at 10 to 15...
# 13  Generally clear. High 30ºC. Winds SSE at 10 to...
# 14  Generally clear. Low 22ºC. Winds W at 10 to 15...
# 15  Generally clear. High 29ºC. NE winds shifting ...
# 16  Generally clear. Low 22ºC. Winds WSW at 10 to ...
# 17  Generally clear. High 28ºC. ENE winds shifting...
# 18  Generally clear. Low 21ºC. Winds WSW at 10 to ...
# 19  Generally clear. High 28ºC. Winds SSE at 15 to...
# 20  Partly cloudy. Low 21ºC. Winds SW at 10 to 15 ...
# 21  Partly cloudy. High 27ºC. NE winds shifting to...
# 22  Partly cloudy. Low 20ºC. Winds SSW at 10 to 15...
# 23  Partly cloudy. High 27ºC. ENE winds shifting t...
# 24  Partly cloudy. Low 20ºC. Winds SW at 10 to 15 ...
# 25  Partly cloudy. High 27ºC. N winds shifting to ...
# 26  Generally clear. Low 20ºC. Winds SSW at 10 to ...
# 27  Partly cloudy. High 27ºC. ENE winds shifting t...
# 28  Generally clear. Low 21ºC. Winds SW at 10 to 1...

# %% [markdown]
# ## Exporting the data to CSV file

# %%
weather.to_csv(f'output\weather.csv', index = False)
